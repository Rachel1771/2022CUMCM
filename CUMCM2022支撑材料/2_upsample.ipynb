# %%
import pandas as pd
from collections import Counter
from imblearn.over_sampling import RandomOverSampler, SMOTE  # 随机采样函数 和SMOTE过采样函数

data = pd.read_excel('excel/result/2/k-means_铅钡.xlsx')
data.head()
# Out:
#    Unnamed: 0    文物采样点  二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  \
# 0           0       02       36.28   0.020016  1.050000      2.34  1.180000
# 1           1       08       20.14   0.127769  0.007344      1.48  0.017329
# 2           2  08严重风化点        4.61   1.257193  0.083635      3.19  0.162292
# 3           3       11       33.59   0.888276  0.210000      3.51  0.710000
# 4           4       19       29.64   0.374655  0.053430      2.93  0.590000
#
#    氧化铝(Al2O3)  氧化铁(Fe2O3)  氧化铜(CuO)  ...  氧化锶(SrO)  氧化锡(SnO2)  二氧化硫(SO2)  \
# 0        5.73    1.860000      0.26  ...      0.19   0.003644   0.028675
# 1        1.34    0.013572     10.41  ...      0.37   0.013985   2.580000
# 2        1.11    0.130625      3.14  ...      0.53   0.126256  15.030000
# 3        2.69    0.123667      4.93  ...      0.37   0.077115   0.910942
# 4        3.57    1.330000      3.51  ...      0.19   0.055317   0.756598
#
#    量化风化  纹饰  颜色  类型  表面风化      总和 聚类类别
# 0     2   2   2  铅钡    风化  100.00    1
# 1     2   1   3  铅钡    风化  100.00    4
# 2     2   1   3  铅钡    风化  100.00    2
# 3     2   1   2  铅钡    风化   97.39    5
# 4     2   2   2  铅钡    风化  100.00    5
#
# [5 rows x 23 columns]

# %%
# 分别获取特征值和标签值
X = data.loc[:,'二氧化硅(SiO2)':'量化风化']
y = data['聚类类别']

# 对标签中的变量进行计数统计
print('原始标签数据统计：', Counter(y))

# 随机过采样方法
ros = RandomOverSampler(random_state=0)  # random_state为0（此数字没有特殊含义，可以换成其他数字）使得每次代码运行的结果保持一致
X_oversampled, y_oversampled = ros.fit_resample(X, y)  # 使用原始数据的特征变量和目标变量生成过采样数据集

print('随机过采样处理后', Counter(y_oversampled))
oversampled = pd.concat([X_oversampled,y_oversampled],axis=1)
oversampled.to_excel('excel/result/2/k-means_铅钡_oversample.xlsx')
oversampled.head()

# # SMOTE法过采样
# smote = SMOTE(random_state=0)  # random_state为0（此数字没有特殊含义，可以换成其他数字）使得每次代码运行的结果保持一致
# X_smotesampled, y_smotesampled = smote.fit_resample(X, y)  # 使用原始数据的特征变量和目标变量生成过采样数据集
# print('Smote法过采样后', Counter(y_smotesampled))
# Out:
# 原始标签数据统计： Counter({3: 15, 5: 12, 0: 9, 1: 8, 4: 3, 2: 2})
# 随机过采样处理后 Counter({1: 15, 4: 15, 2: 15, 5: 15, 0: 15, 3: 15})
#    二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  \
# 0       36.28   0.020016  1.050000      2.34  1.180000        5.73
# 1       20.14   0.127769  0.007344      1.48  0.017329        1.34
# 2        4.61   1.257193  0.083635      3.19  0.162292        1.11
# 3       33.59   0.888276  0.210000      3.51  0.710000        2.69
# 4       29.64   0.374655  0.053430      2.93  0.590000        3.57
#
#    氧化铁(Fe2O3)  氧化铜(CuO)  氧化铅(PbO)   氧化钡(BaO)  五氧化二磷(P2O5)  氧化锶(SrO)  \
# 0    1.860000      0.26     47.43   0.057665         3.57      0.19
# 1    0.013572     10.41     28.68  31.230000         3.59      0.37
# 2    0.130625      3.14     32.45  30.620000         7.56      0.53
# 3    0.123667      4.93     25.39  14.610000         9.38      0.37
# 4    1.330000      3.51     42.82   5.350000         8.83      0.19
#
#    氧化锡(SnO2)  二氧化硫(SO2)  量化风化  聚类类别
# 0   0.003644   0.028675     2     1
# 1   0.013985   2.580000     2     4
# 2   0.126256  15.030000     2     2
# 3   0.077115   0.910942     2     5
# 4   0.055317   0.756598     2     5

# %%
data = pd.read_excel('excel/result/2/k-means_高钾.xlsx')
data.head()
# Out:
#    Unnamed: 0 文物采样点  二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  \
# 0           0    07       92.63   0.033598  0.042751      1.07  0.006069
# 1           1    09       95.02   0.020206  0.590000      0.62  0.005404
# 2           2    10       96.77   0.015791  0.920000      0.21  0.003872
# 3           3    12       94.29   0.038818  1.010000      0.72  0.010529
# 4           4    22       92.35   0.000000  0.740000      1.66  0.640000
#
#    氧化铝(Al2O3)  氧化铁(Fe2O3)  氧化铜(CuO)  ...  氧化锡(SnO2)  二氧化硫(SO2)  量化风化  纹饰  颜色  \
# 0        1.98        0.17      3.24  ...   0.007037   0.047864     2   3   1
# 1        1.32        0.32      1.55  ...   0.005506   0.043539     2   3   1
# 2        0.81        0.26      0.84  ...   0.003911   0.034204     2   3   1
# 3        1.46        0.29      1.65  ...   0.011114   0.086089     2   3   1
# 4        3.50        0.35      0.55  ...   0.000000   0.000000     2   3   1
#
#    类型  表面风化     总和  label 聚类类别
# 0  高钾    风化  100.0      0    2
# 1  高钾    风化  100.0      0    2
# 2  高钾    风化  100.0      0    2
# 3  高钾    风化  100.0      0    2
# 4  高钾    风化  100.0      0    2
#
# [5 rows x 24 columns]

# %%
# 分别获取特征值和标签值
X = data.loc[:,'二氧化硅(SiO2)':'量化风化']
y = data['聚类类别']

# 对标签中的变量进行计数统计
print('原始标签数据统计：', Counter(y))

# 随机过采样方法
ros = RandomOverSampler(random_state=0)  # random_state为0（此数字没有特殊含义，可以换成其他数字）使得每次代码运行的结果保持一致
X_oversampled, y_oversampled = ros.fit_resample(X, y)  # 使用原始数据的特征变量和目标变量生成过采样数据集

print('随机过采样处理后', Counter(y_oversampled))

oversampled = pd.concat([X_oversampled, y_oversampled], axis=1)
oversampled.to_excel('excel/result/2/k-means_高钾_oversample.xlsx')
oversampled.head()
# # SMOTE法过采样
# smote = SMOTE(random_state=0)  # random_state为0（此数字没有特殊含义，可以换成其他数字）使得每次代码运行的结果保持一致
# X_smotesampled, y_smotesampled = smote.fit_resample(X, y)  # 使用原始数据的特征变量和目标变量生成过采样数据集
# print('Smote法过采样后', Counter(y_smotesampled))
# Out:
# 原始标签数据统计： Counter({2: 7, 1: 7, 3: 2, 0: 1})
# 随机过采样处理后 Counter({2: 7, 1: 7, 3: 7, 0: 7})
#    二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  \
# 0       92.63   0.033598  0.042751      1.07  0.006069        1.98
# 1       95.02   0.020206  0.590000      0.62  0.005404        1.32
# 2       96.77   0.015791  0.920000      0.21  0.003872        0.81
# 3       94.29   0.038818  1.010000      0.72  0.010529        1.46
# 4       92.35   0.000000  0.740000      1.66  0.640000        3.50
#
#    氧化铁(Fe2O3)  氧化铜(CuO)  氧化铅(PbO)  氧化钡(BaO)  五氧化二磷(P2O5)  氧化锶(SrO)  氧化锡(SnO2)  \
# 0        0.17      3.24  0.094143  0.067232     0.610000  0.001306   0.007037
# 1        0.32      1.55  0.080138  0.073653     0.350000  0.001554   0.005506
# 2        0.26      0.84  0.071839  0.057292     0.001724  0.001368   0.003911
# 3        0.29      1.65  0.161503  0.118610     0.150000  0.003337   0.011114
# 4        0.35      0.55  0.000000  0.000000     0.210000  0.000000   0.000000
#
#    二氧化硫(SO2)  量化风化  聚类类别
# 0   0.047864     2     2
# 1   0.043539     2     2
# 2   0.034204     2     2
# 3   0.086089     2     2
# 4   0.000000     2     2
