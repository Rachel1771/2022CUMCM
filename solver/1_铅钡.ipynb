# %%
import pandas as pd
import numpy as np

# %%
data_origin =pd.read_excel('excel//extract//1//铅钡归一化.xlsx')
data_origin.head()
# Out:
#    二氧化硅(SiO2)_归一化  氧化钠(Na2O)_归一化  氧化钾(K2O)_归一化  氧化钙(CaO)_归一化  氧化镁(MgO)_归一化  \
# 0        0.019046       0.000339      0.098027      0.022855      0.034453
# 1        0.010573       0.002164      0.000686      0.014455      0.000506
# 2        0.002420       0.021297      0.007808      0.031157      0.004738
# 3        0.017633       0.015048      0.019605      0.034282      0.020730
# 4        0.015560       0.006347      0.004988      0.028617      0.017226
#
#    氧化铝(Al2O3)_归一化  氧化铁(Fe2O3)_归一化  氧化铜(CuO)_归一化  氧化铅(PbO)_归一化  氧化钡(BaO)_归一化  \
# 0        0.031885        0.052374      0.002787      0.029025      0.000112
# 1        0.007456        0.000382      0.111598      0.017551      0.060563
# 2        0.006177        0.003678      0.033662      0.019858      0.059380
# 3        0.014969        0.003482      0.052851      0.015538      0.028333
# 4        0.019865        0.037451      0.037628      0.026204      0.010375
#
# ...

# %%
data = data_origin.loc[:, '二氧化硅(SiO2)_归一化':'量化风化']
data.head()
# Out:
#    二氧化硅(SiO2)_归一化  氧化钠(Na2O)_归一化  氧化钾(K2O)_归一化  氧化钙(CaO)_归一化  氧化镁(MgO)_归一化  \
# 0        0.019046       0.000339      0.098027      0.022855      0.034453
# 1        0.010573       0.002164      0.000686      0.014455      0.000506
# 2        0.002420       0.021297      0.007808      0.031157      0.004738
# 3        0.017633       0.015048      0.019605      0.034282      0.020730
# 4        0.015560       0.006347      0.004988      0.028617      0.017226
#
#    氧化铝(Al2O3)_归一化  氧化铁(Fe2O3)_归一化  氧化铜(CuO)_归一化  氧化铅(PbO)_归一化  氧化钡(BaO)_归一化  \
# 0        0.031885        0.052374      0.002787      0.029025      0.000112
# 1        0.007456        0.000382      0.111598      0.017551      0.060563
# 2        0.006177        0.003678      0.033662      0.019858      0.059380
# 3        0.014969        0.003482      0.052851      0.015538      0.028333
# 4        0.019865        0.037451      0.037628      0.026204      0.010375
#
# ...

# %%
comp_list = list(data.columns)
before_comp = []
print(comp_list)
# Out:
# ['二氧化硅(SiO2)_归一化', '氧化钠(Na2O)_归一化', '氧化钾(K2O)_归一化', '氧化钙(CaO)_归一化', '氧化镁(MgO)_归一化', '氧化铝(Al2O3)_归一化', '氧化铁(Fe2O3)_归一化', '氧化铜(CuO)_归一化', '氧化铅(PbO)_归一化', '氧化钡(BaO)_归一化', '五氧化二磷(P2O5)_归一化', '氧化锶(SrO)_归一化', '氧化锡(SnO2)_归一化', '二氧化硫(SO2)_归一化', '量化风化']

# %%
Na2O_list=[]
BaO_list=[]
Fe2O3_list=[]
K2O_list=[]
MgO_list=[]
SrO_list=[]
SO2_list=[]
P2O5_list=[]
CaO_list=[]
PbO_list=[]
CuO_list=[]
Al2O3_list=[]
SnO2_list=[]
SiO2_list=[]
for i in range(data.shape[0]):
    Na2O_list.append(0.034-0.366 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.113 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]-0.238 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]+0.231 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.066 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.108 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.037 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.666 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]-0.131 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]-0.188 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.072 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.009 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]+0.028 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]+0.013 * data.iloc[i,comp_list.index('量化风化')])
    BaO_list.append(0.047-0.582 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]-0.671 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.019 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.043 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]-0.091 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]-0.107 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.1 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.033 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]+0.233 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.101 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.023 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.046 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]+0.12 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.001 * data.iloc[i,comp_list.index('量化风化')])
    Fe2O3_list.append(0.004-0.041 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.138 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.077 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.29 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.45 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]-0.008 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.058 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.306 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]-0.173 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]+0.12 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]-0.001 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.137 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]-0.08 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]+0.01 * data.iloc[i,comp_list.index('量化风化')])
    K2O_list.append(-0.001-0.344 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.078 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.097 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]+0.238 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]+0.247 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]+0.283 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.104 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]+0.121 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]+0.216 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]-0.083 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]-0.172 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]-0.058 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]+0.025 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]+0.009 * data.iloc[i,comp_list.index('量化风化')])
    MgO_list.append(0.013+0.055 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]+0.272 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]+0.064 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.094 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.136 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.004 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.062 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.239 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]-0.218 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]+0.136 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.149 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.066 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]-0.062 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.001 * data.iloc[i,comp_list.index('量化风化')])
    SrO_list.append(-0.0-0.46 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]+0.067 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.017 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]-0.058 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]-0.104 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]+0.126 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]+0.093 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.001 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]+0.075 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]+0.648 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]+0.041 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]+0.009 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]+0.041 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]+0.007 * data.iloc[i,comp_list.index('量化风化')])
    SO2_list.append(0.054-0.867 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.042 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]+0.04 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.051 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.366 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]-0.32 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.25 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.159 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.517 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-1.359 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]+1.243 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]+0.169 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.249 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]-0.004 * data.iloc[i,comp_list.index('量化风化')])
    P2O5_list.append(0.069-0.801 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.338 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]-0.088 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]-0.056 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.295 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]+0.233 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.052 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]+0.079 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]+0.047 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.721 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]+0.134 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]-0.128 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]+0.056 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.014 * data.iloc[i,comp_list.index('量化风化')])
    CaO_list.append(0.021-0.558 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]+0.027 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]-0.047 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.194 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]+0.129 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]+0.124 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]+0.04 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]+0.156 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]-0.129 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]+0.123 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]-0.089 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.038 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]+0.051 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.001 * data.iloc[i,comp_list.index('量化风化')])
    PbO_list.append(0.046-0.058 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.472 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.027 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.007 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.032 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]-0.034 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.129 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.017 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.164 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]-0.06 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.11 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]-0.019 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]-0.038 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.005 * data.iloc[i,comp_list.index('量化风化')])
    CuO_list.append(0.038-0.496 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]-0.045 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.02 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]-0.084 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.114 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]-0.125 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.059 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.827 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]+0.953 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]+0.056 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.179 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]-0.145 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]-0.205 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.002 * data.iloc[i,comp_list.index('量化风化')])
    Al2O3_list.append(0.036+0.07 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]+0.129 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]-0.018 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]+0.093 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.171 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]-0.051 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.027 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.857 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]-0.191 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]-0.03 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]+0.106 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.143 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]-0.046 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.003 * data.iloc[i,comp_list.index('量化风化')])
    SnO2_list.append(0.027+0.086 * data.iloc[i,comp_list.index('二氧化硅(SiO2)_归一化')]+0.035 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.008 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]-0.073 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]+0.168 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]+0.211 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]+0.482 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]+0.168 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.226 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.406 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]+0.292 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]-0.238 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]-0.026 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]-0.011 * data.iloc[i,comp_list.index('量化风化')])
    SiO2_list.append(0.033-0.014 * data.iloc[i,comp_list.index('氧化钠(Na2O)_归一化')]-0.018 * data.iloc[i,comp_list.index('氧化钾(K2O)_归一化')]-0.105 * data.iloc[i,comp_list.index('氧化钙(CaO)_归一化')]+0.008 * data.iloc[i,comp_list.index('氧化镁(MgO)_归一化')]+0.011 * data.iloc[i,comp_list.index('氧化铝(Al2O3)_归一化')]-0.002 * data.iloc[i,comp_list.index('氧化铁(Fe2O3)_归一化')]-0.033 * data.iloc[i,comp_list.index('氧化铜(CuO)_归一化')]-0.444 * data.iloc[i,comp_list.index('氧化铅(PbO)_归一化')]-0.177 * data.iloc[i,comp_list.index('氧化钡(BaO)_归一化')]-0.063 * data.iloc[i,comp_list.index('五氧化二磷(P2O5)_归一化')]-0.072 * data.iloc[i,comp_list.index('氧化锶(SrO)_归一化')]+0.004 * data.iloc[i,comp_list.index('氧化锡(SnO2)_归一化')]-0.023 * data.iloc[i,comp_list.index('二氧化硫(SO2)_归一化')]+0.004 * data.iloc[i,comp_list.index('量化风化')])

# %%
data={
    '二氧化硅(SiO2)': SiO2_list, '氧化钠(Na2O)': Na2O_list, '氧化钾(K2O)': K2O_list, '氧化钙(CaO)': CaO_list,
    '氧化镁(MgO)': MgO_list, '氧化铝(Al2O3)':Al2O3_list , '氧化铁(Fe2O3)': Fe2O3_list, '氧化铜(CuO)': CuO_list,
    '氧化铅(PbO)': PbO_list, '氧化钡(BaO)': BaO_list, '五氧化二磷(P2O5)': P2O5_list, '氧化锶(SrO)': SrO_list,
    '氧化锡(SnO2)': SnO2_list, '二氧化硫(SO2)':SO2_list
}
pred_first = pd.DataFrame(data)
pred_first
# Out:
#     二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  \
# 0     0.022197   0.013976  0.043091  0.034662  0.029075    0.021708
# 1     0.013657   0.026830  0.015552  0.016123 -0.003445    0.003960
# 2     0.007388   0.028091  0.027862  0.029530  0.002396    0.002205
# 3     0.018151   0.021808  0.016515  0.022401  0.023825    0.022487
# 4     0.019020   0.016382  0.028512  0.031395  0.021018    0.011360
# 5     0.013055   0.027183  0.014255  0.014495 -0.003900    0.003954
# 6     0.006030   0.026593  0.029923  0.027443 -0.000828    0.001934
# 7     0.021813   0.026793  0.020936  0.015628  0.008112    0.008696
# 8     0.023316   0.031168  0.017422  0.011379  0.008367    0.009204
# 9     0.020878   0.029356  0.018812  0.014210  0.009840    0.006740
# 10    0.017268   0.026844  0.014556  0.015354  0.009107    0.002657
# 11    0.013837   0.022332  0.017772  0.019043  0.011226   -0.001118
# 12    0.015331   0.025584  0.052807  0.045233  0.032002    0.028423
# ...

# %%
data_origin.loc[:, '二氧化硅(SiO2)':'二氧化硫(SO2)']
# Out:
#     二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  \
# 0        36.28   0.020016  1.050000  2.340000  1.180000        5.73
# 1        20.14   0.127769  0.007344  1.480000  0.017329        1.34
# 2         4.61   1.257193  0.083635  3.190000  0.162292        1.11
# 3        33.59   0.888276  0.210000  3.510000  0.710000        2.69
# 4        29.64   0.374655  0.053430  2.930000  0.590000        3.57
# 5        19.79   0.127440  0.007613  1.440000  0.017736        0.70
# 6         3.72   0.082525  0.400000  3.010000  0.011047        1.18
# 7        35.78   0.501757  0.250000  0.780000  0.171059        1.62
# 8        39.57   2.220000  0.140000  0.370000  0.154675        1.60
# 9        32.93   1.380000  0.060885  0.680000  0.135710        2.57
# 10       26.25   0.194224  0.036811  1.110000  0.100582        0.50
# 11       16.71   0.280372  0.036979  1.870000  0.064909        0.45
# 12       18.46   0.625358  0.440000  4.960000  2.730000        3.33
# ...

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler


data_origin = pd.read_excel('./excel/extract/1/铅钡归一化.xlsx', sheet_name='无风化')

stand_scaler = StandardScaler()
std_data = stand_scaler.fit_transform(data_origin.loc[:,'二氧化硅(SiO2)':'二氧化硫(SO2)'])
origin_std_data = stand_scaler.inverse_transform(pred_first) # 逆标准化

col = [
    '二氧化硅(SiO2)', '氧化钠(Na2O)', '氧化钾(K2O)', '氧化钙(CaO)',
    '氧化镁(MgO)', '氧化铝(Al2O3)', '氧化铁(Fe2O3)', '氧化铜(CuO)',
    '氧化铅(PbO)', '氧化钡(BaO)', '五氧化二磷(P2O5)', '氧化锶(SrO)',
    '氧化锡(SnO2)', '二氧化硫(SO2)'
]
pred = pd.DataFrame(origin_std_data,columns=col)
pred.to_excel('./excel/result/1/铅钡.xlsx')
pred
# Out:
#     二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  \
# 0    55.356106   2.037003  0.278637  1.349066  0.728893    4.540354
# 1    55.256700   2.064869  0.270713  1.327463  0.713553    4.482463
# 2    55.183723   2.067602  0.274255  1.343086  0.716308    4.476739
# 3    55.309012   2.053981  0.270990  1.334778  0.726417    4.542893
# 4    55.319130   2.042217  0.274442  1.345258  0.725093    4.506599
# 5    55.249698   2.065635  0.270340  1.325565  0.713338    4.482443
# 6    55.167923   2.064356  0.274848  1.340654  0.714787    4.475854
# 7    55.351635   2.064788  0.272262  1.326886  0.719005    4.497911
# 8    55.369140   2.074272  0.271251  1.321935  0.719125    4.499568
# 9    55.340755   2.070344  0.271651  1.325233  0.719820    4.491530
# 10   55.298736   2.064899  0.270426  1.326567  0.719474    4.478213
# 11   55.258799   2.055118  0.271352  1.330865  0.720474    4.465900
# 12   55.276182   2.062168  0.281432  1.361384  0.730274    4.562256
# ...
